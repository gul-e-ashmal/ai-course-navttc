# %% [markdown]
# # Titanic Data Analysis Assignment (Advanced Pandas & NumPy)
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Dataset
# Use the Titanic dataset.

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# **Check the first 10 rows of the dataset.**

# %%
# Your code here

# %% [markdown]
# **Display dataset shape and column data types.**

# %%
# Your code here

# %% [markdown]
# **Identify missing values and compute percentage missing per column.**

# %%
# Your code here

# %% [markdown]
# **Handle missing values in 'Age' using group-wise median based on 'Pclass' and 'Sex'.**

# %%
# Your code here

# %% [markdown]
# **Create a new feature 'FamilySize' using SibSp and Parch.**

# %%
# Your code here

# %% [markdown]
# **Find correlation matrix and identify top 3 features correlated with 'Survived'.**

# %%
# Your code here

# %% [markdown]
# **Perform groupby on 'Pclass' and compute survival rate.**

# %%
# Your code here

# %% [markdown]
# **Find average fare paid by passengers grouped by embarkation port.**

# %%
# Your code here

# %% [markdown]
# **Detect and handle outliers in 'Fare' using IQR method.**

# %%
# Your code here

# %% [markdown]
# **Create age bins and analyze survival distribution across bins.**

# %%
# Your code here

# %% [markdown]
# **Use pivot_table to summarize survival by Sex and Pclass.**

# %%
# Your code here

# %% [markdown]
# **Normalize 'Fare' column using Min-Max scaling.**

# %%
# Your code here

# %% [markdown]
# **Apply lambda function to create 'IsAlone' feature.**

# %%
# Your code here

# %% [markdown]
# **Find duplicate rows and remove them.**

# %%
# Your code here

# %% [markdown]
# **Sort dataset by Fare descending and display top 15.**

# %%
# Your code here

# %% [markdown]
# **Use NumPy to compute z-score for 'Age' column.**

# %%
# Your code here

# %% [markdown]
# **Filter passengers with high fare (>95th percentile).**

# %%
# Your code here

# %% [markdown]
# **Merge dataset with itself to simulate joins (practice purpose).**

# %%
# Your code here

# %% [markdown]
# **Create multi-index using Pclass and Sex.**

# %%
# Your code here

# %% [markdown]
# **Export cleaned dataset to new CSV.**

# %%
# Your code here

# %%
nested = [1,2,3,[4,5,['target','google']]]
nested[3][2][0]
# Out:
# 'target'

# %%
nested[3][2][0:]
# Out:
# ['target', 'google']

# %%
nested[0:3]
# Out:
# [1, 2, 3]

# %%
my_list=[1,2,3,4]
my_list[:2]
# Out:
# [1, 2]

# %% [markdown]
# List Comprehension

# %%
oyut = [item**2 for item in my_list]
oyut
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# Lambda Function

# %%
def times2(var):
    return var**2

map(times2,my_list)

# list(map(times2,my_list))

# %%
str1='1,2,3,4,4'
str1.split(',')
# Out:
# ['1', '2', '3', '4', '4']

# %%
#  operation 'in'
1 in [1,2,3,4]
# Out:
# True
